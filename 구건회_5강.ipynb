# %% [markdown]
# <a href="https://colab.research.google.com/github/GooGunHwoe/GGH_1801303/blob/main/%EA%B5%AC%EA%B1%B4%ED%9A%8C_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(5,5))
df.columns=['A','B','C','D','E']
df.iloc[1,1]=np.nan
df.iloc[2,2]=np.nan
df
# Out:
#           A         B         C         D         E
# 0 -0.355526  1.904356 -0.353049 -1.307494 -2.494024
# 1  0.135176       NaN -0.664484  0.193864 -0.213783
# 2  0.291658  0.011623       NaN  0.626849 -2.034103
# 3  1.631688  0.595908  1.803836  0.851963 -0.261665
# 4  0.701655 -0.831297  0.846547  0.856530 -1.076285

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False   True  False  False  False
# 2  False  False   True  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
df['A'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df['C'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: C, dtype: bool

# %%
df['B'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: B, dtype: bool

# %%
df[df['B'].isnull()]
# Out:
#           A   B         C         D         E
# 1  0.135176 NaN -0.664484  0.193864 -0.213783

# %%
df.isnull().sum()
# Out:
# A    0
# B    1
# C    1
# D    0
# E    0
# dtype: int64

# %%
df['B'].isnull().sum()
# Out:
# 1

# %%
df.dropna()
# Out:
#           A         B         C         D         E
# 0 -0.355526  1.904356 -0.353049 -1.307494 -2.494024
# 3  1.631688  0.595908  1.803836  0.851963 -0.261665
# 4  0.701655 -0.831297  0.846547  0.856530 -1.076285

# %%
df.dropna(inplace=True)
df
# Out:
#           A         B         C         D         E
# 0 -0.355526  1.904356 -0.353049 -1.307494 -2.494024
# 3  1.631688  0.595908  1.803836  0.851963 -0.261665
# 4  0.701655 -0.831297  0.846547  0.856530 -1.076285

# %%
df.dropna(subset=['B'], axis=0, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0 -0.355526  1.904356 -0.353049 -1.307494 -2.494024
# 3  1.631688  0.595908  1.803836  0.851963 -0.261665
# 4  0.701655 -0.831297  0.846547  0.856530 -1.076285

# %%
df.dropna(axis=1, inplace=True)
df
# Out:
#           A         B         C         D         E
# 0 -0.355526  1.904356 -0.353049 -1.307494 -2.494024
# 3  1.631688  0.595908  1.803836  0.851963 -0.261665
# 4  0.701655 -0.831297  0.846547  0.856530 -1.076285

# %%
robots = [[24,23680], [35, np.nan], [46,47350], [27,np.nan]]
data = pd.DataFrame(robots, columns=['max_spped','price'])
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35      NaN
# 2         46  47350.0
# 3         27      NaN

# %%
mean = data['price'].mean()
data.replace(np.nan, mean, inplace=True)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35  35515.0
# 2         46  47350.0
# 3         27  35515.0

# %%
mean = data['price'].mean()
data.replace(np.nan, mean)
data
# Out:
#    max_spped    price
# 0         24  23680.0
# 1         35  35515.0
# 2         46  47350.0
# 3         27  35515.0

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
vals = iris['sepal_length'].values
sns.kdeplot(vals)
plt.title("kdeplot for sepal length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-cf3e9e784d0d> in <module>()
#       1 vals = iris['sepal_length'].values
#       2 sns.kdeplot(vals)
# ----> 3 plt.title("kdeplot for sepal length")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
vals = iris['petal_length'].values
sns.kdeplot(vals)
plt.title("kdeplot for petal length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-621bcf9a005b> in <module>()
#       1 vals = iris['petal_length'].values
#       2 sns.kdeplot(vals)
# ----> 3 plt.title("kdeplot for petal length")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
vals=iris['petal_length'].values
sns.distplot(vals, kde=True, rug=True)
plt.title("displot for petal length")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c53234b28d49> in <module>()
#       1 vals=iris['petal_length'].values
#       2 sns.distplot(vals, kde=True, rug=True)
# ----> 3 plt.title("displot for petal length")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.displot(vals, kde=True, rug=True)
plt.title("displot for petal length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a06cb8bc54f5> in <module>()
#       1 sns.displot(vals, kde=True, rug=True)
# ----> 2 plt.title("displot for petal length")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.rugplot(vals)

# %%
sns.histplot(vals, kde=True)
plt.title("histplot for petal length")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-5304da4469ec> in <module>()
#       1 sns.histplot(vals, kde=True)
# ----> 2 plt.title("histplot for petal length")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
titanic = sns.load_dataset("titanic") # 타이타닉호 데이터
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x="adult_male", data=titanic)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-6f16c5d57c02> in <module>()
#       1 sns.countplot(x="adult_male", data=titanic)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
titanic.adult_male
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: adult_male, Length: 891, dtype: bool

# %%
tips = sns.load_dataset("tips") #팁 데이터
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x="day", data=tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-a1538bee5b13> in <module>()
#       1 sns.countplot(x="day", data=tips)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind='scatter')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-803bc0a5cee9> in <module>()
#       1 sns.jointplot(x='sepal_length', y='sepal_width', data=iris, kind='scatter')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris, hue='species',kind='kde')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-b064924e8cff> in <module>()
#       1 sns.jointplot(x='sepal_length', y='sepal_width', data=iris, hue='species',kind='kde')
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.pairplot(iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-153dd1dc8e63> in <module>()
#       1 sns.pairplot(iris)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.pairplot(iris, hue='species', markers=['o','s','d'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-0cfbcdff3d70> in <module>()
#       1 sns.pairplot(iris, hue='species', markers=['o','s','d'])
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
titanic_size=titanic.pivot_table(index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size)
plt.title("Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-108289a290f1> in <module>()
#       1 sns.heatmap(titanic_size)
# ----> 2 plt.title("Heatmap")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.heatmap(titanic_size, annot=True)
plt.title("Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-0509596fd0ff> in <module>()
#       1 sns.heatmap(titanic_size, annot=True)
# ----> 2 plt.title("Heatmap")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.heatmap(titanic_size, annot=True, fmt='d')
plt.title("Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-58c6c6cc5671> in <module>()
#       1 sns.heatmap(titanic_size, annot=True, fmt='d')
# ----> 2 plt.title("Heatmap")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.heatmap(titanic_size, cmap=sns.color_palette("PuBu"), annot=True, fmt='d')
plt.title("Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-e73bc059b033> in <module>()
#       1 sns.heatmap(titanic_size, cmap=sns.color_palette("PuBu"), annot=True, fmt='d')
# ----> 2 plt.title("Heatmap")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("Tips on each day")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-3ab68882a0bb> in <module>()
#       1 sns.barplot(x="day", y="total_bill", data=tips)
# ----> 2 plt.title("Tips on each day")
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.barplot(x='total_bill', y='day',data=tips)
plt.title('tips on each day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-f6237d894762> in <module>()
#       1 sns.barplot(x='total_bill', y='day',data=tips)
# ----> 2 plt.title('tips on each day')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.stripplot(x='day', y='total_bill',data=tips, jitter=True)
plt.title('Tips on each day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-36ba0e25247f> in <module>()
#       1 sns.stripplot(x='day', y='total_bill',data=tips, jitter=True)
# ----> 2 plt.title('Tips on each day')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.stripplot(x='day', y='total_bill',data=tips, jitter=False)
plt.title('Tips on each day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-2f459bbf58fd> in <module>()
#       1 sns.stripplot(x='day', y='total_bill',data=tips, jitter=False)
# ----> 2 plt.title('Tips on each day')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.swarmplot(x='day', y='total_bill',data=tips)
plt.title('Tips on each day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-608991326da0> in <module>()
#       1 sns.swarmplot(x='day', y='total_bill',data=tips)
# ----> 2 plt.title('Tips on each day')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.violinplot(x='day', y='total_bill',data=tips)
plt.title('Tips on each day')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-0f82b4c0fabd> in <module>()
#       1 sns.violinplot(x='day', y='total_bill',data=tips)
# ----> 2 plt.title('Tips on each day')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-1feecc607f1c> in <module>()
#       1 sns.barplot(x='day', y='total_bill', hue='sex', data=tips)
# ----> 2 plt.title('Tips on each day with hue=sex')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.barplot(x='day', y='total_bill', hue='time', data=tips)
plt.title('Tips on each day with hue=time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-054ae9c1604b> in <module>()
#       1 sns.barplot(x='day', y='total_bill', hue='time', data=tips)
# ----> 2 plt.title('Tips on each day with hue=time')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.stripplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-834ed345a4ce> in <module>()
#       1 sns.stripplot(x='day', y='total_bill', hue='sex', data=tips)
# ----> 2 plt.title('Tips on each day with hue=sex')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.swarmplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-05cf4cc5ccff> in <module>()
#       1 sns.swarmplot(x='day', y='total_bill', hue='sex', data=tips)
# ----> 2 plt.title('Tips on each day with hue=sex')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips)
plt.title('Tips on each day with hue=sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-6ce80384ccba> in <module>()
#       1 sns.violinplot(x='day', y='total_bill', hue='sex', data=tips)
# ----> 2 plt.title('Tips on each day with hue=sex')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.violinplot(x='day', y='total_bill', hue='sex', data=tips, split=True)
plt.title('Tips on each day with hue=sex and split=True')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-ab24dbee1c1a> in <module>()
#       1 sns.violinplot(x='day', y='total_bill', hue='sex', data=tips, split=True)
# ----> 2 plt.title('Tips on each day with hue=sex and split=True')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.stripplot(x='day', y='total_bill', hue='sex', data=tips, dodge=True)
plt.title('Tips on each day with hue=sex and dodge=True')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-58440644b935> in <module>()
#       1 sns.stripplot(x='day', y='total_bill', hue='sex', data=tips, dodge=True)
# ----> 2 plt.title('Tips on each day with hue=sex and dodge=True')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.swarmplot(x='day', y='total_bill', hue='sex', data=tips, dodge=True)
plt.title('Tips on each day with hue=sex and dodge=True')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-5fffe205c906> in <module>()
#       1 sns.swarmplot(x='day', y='total_bill', hue='sex', data=tips, dodge=True)
# ----> 2 plt.title('Tips on each day with hue=sex and dodge=True')
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.catplot(x="age", y="sex", hue="survived", row="class", data=titanic,
            kind="violin", split=True, height=2, aspect=4)
plt.title("Catplot of titanic with hue=survived")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-61d2ec77e8c0> in <module>()
#       1 sns.catplot(x="age", y="sex", hue="survived", row="class", data=titanic,
#       2             kind="violin", split=True, height=2, aspect=4)
# ----> 3 plt.title("Catplot of titanic with hue=survived")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.title("violinplot and swarmplot")
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='0.9')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-72a239f31efd> in <module>()
# ----> 1 plt.title("violinplot and swarmplot")
#       2 sns.violinplot(x='day', y='total_bill', data=tips)
#       3 sns.swarmplot(x='day', y='total_bill', data=tips, color='0.9')
#       4 plt.show()
#
# NameError: name 'plt' is not defined
